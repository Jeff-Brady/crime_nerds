# %%
import pandas as pd

# %%
file = '/Users/p/Downloads/neueFische/crime_nerds/Crime_Data/Crime_Data.csv'
df = pd.read_csv(file)
# Out:
# /var/folders/nj/j2fgh2k95cq716x6zcd11chc0000gn/T/ipykernel_16821/1642304585.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file)
#         complaint_id report_date                         offense   crime_type  \
# 0            9931520  2006-01-01  Criminal mischief & related of  Misdemeanor
# 1           10205105  2006-01-01                   Harrassment 2    Violation
# 2           10021766  2006-01-01                   Petit larceny  Misdemeanor
# 3            9934843  2006-01-01    Assault 3 & related offenses  Misdemeanor
# 4            9966053  2006-01-01  Offenses against public admini  Misdemeanor
# ...              ...         ...                             ...          ...
# 8848204    279761671  2023-12-31                   Petit larceny  Misdemeanor
# 8848205    279749438  2023-12-31                   Petit larceny  Misdemeanor
# ...

# %%
from sql_functions import get_engine

# %%
engine = get_engine()
# Out:
# {'host': 'data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com', 'port': '5432', 'database': 'postgres', 'user': 'patrickschaefer', 'password': 'M1nCrFUB3f0VubAT'}
# Engine(postgresql://user:***@host/database)

# %%
table_name = 'crime_data'
schema = 'capstone_crime_nerds'

# %%
import psycopg2

# %%
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        df.to_sql(name = table_name, # Name of SQL table variable
                        con = engine, # Engine or connection
                        schema = schema, # your class schema variable
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The crime_data table was imported successfully.
